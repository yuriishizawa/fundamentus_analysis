# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fundamentus_analysis.get_data import FundamentusData

# %%
df = FundamentusData().get_df()

# %%
df.sort_values(
    ["EV/EBITDA", "P/L", "Mrg. Líq.", "P/VP"], ascending=[True, True, False, True]
).head(20).reset_index(drop=True)
# Out:
#      Papel  EV/EBIT  EV/EBITDA    P/L  P/VP  Div.Yield  Mrg. Líq.  \
# 0    PSSA3     0.25       0.24   8.21  1.50     0.0627     0.0715
# 1    GOAU4     2.07       1.48   5.41  0.66     0.1368     0.0967
# 2    PETR4     3.26       2.47   4.36  1.43     0.1748     0.2445
# 3    PETR3     3.41       2.58   4.66  1.52     0.1638     0.2445
# 4    TIMS3     7.89       3.32  13.88  1.63     0.0598     0.1212
# 5    VALE3     4.21       3.55   7.56  1.56     0.1083     0.1900
# 6    LREN3     4.99       3.56  14.20  1.50     0.0433     0.0776
# 7    CMIN3     4.36       3.69   7.72  2.31     0.0646     0.2020
# 8   SAPR11     4.65       3.93   5.22  0.81     0.0562     0.2391
# 9    RAPT4     4.99       4.05  10.02  1.19     0.0560     0.0591
# 10   CSMG3     5.75       4.08   5.28  0.95     0.1843     0.1849
# 11   RAIZ4     7.21       4.09   7.96  1.42     0.0631     0.0187
# 12   VIVT3    11.41       4.12  14.78  1.10     0.0582     0.0964
# ...
